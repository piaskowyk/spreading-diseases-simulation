# %%
import matplotlib.pyplot as plt
import pandas as pd
from pandas import DataFrame
import numpy as np
import math
from matplotlib.pyplot import figure
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("19-06-2021_21-28-32.csv")

# %%
colors = ['#505050', '#40ff40', '#ff0d29', '#000000', '#9129a6', '#ffb60d', '#29a629']

# %%
plt.figure(figsize=(10, 7))
plt.title("title")
plt.xlabel("x")
plt.ylabel("y")

# plt.plot(df['epoch'], df['all_agents'], '-', label='all_agents', color=colors[0])
plt.plot(df['epoch'], df['health'], '-', label='health', color=colors[1])
plt.plot(df['epoch'], df['sick'], '-', label='sick', color=colors[2])
plt.plot(df['epoch'], df['death'], '-', label='death', color=colors[3])
plt.plot(df['epoch'], df['quarantine'], '-', label='quarantine', color=colors[4])
plt.plot(df['epoch'], df['infected'], '-', label='infected', color=colors[5])
plt.plot(df['epoch'], df['recovered'], '-', label='recovered', color=colors[6])

# plt.ylim(0, 100)
plt.ylim(0)
plt.legend()
plt.tight_layout()
plt.grid()

plt.show()

# %%
plt.figure(figsize=(10, 7))
plt.title("title")
plt.xlabel("x")
plt.ylabel("y")

plt.plot(df['epoch'], df['all_agents'], '-', label='all_agents', color=colors[0])
plt.plot(df['epoch'], df['all_health'], '-', label='all_health', color=colors[1])
plt.plot(df['epoch'], df['all_sick'], '-', label='all_sick', color=colors[2])
plt.plot(df['epoch'], df['all_death'], '-', label='all_death', color=colors[3])
plt.plot(df['epoch'], df['all_quarantine'], '-', label='all_quarantine', color=colors[4])
plt.plot(df['epoch'], df['all_infected'], '-', label='all_infected', color=colors[5])
plt.plot(df['epoch'], df['all_recovered'], '-', label='all_recovered', color=colors[6])

plt.ylim(0)
plt.legend()
plt.tight_layout()
plt.grid()

plt.show()
